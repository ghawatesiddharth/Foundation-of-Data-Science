# %%
import pandas as pd

# %%
df = pd.read_csv("employee_dataset.csv")

# %%
df.head()
# Out:
#    EmpID        Name  Age  Gender Department   Salary JoiningDate  \
# 0      1  Employee_1   50  Female      Sales  90000.0  2015-01-01
# 1      2  Employee_2   36    Male    Finance  62500.0  2015-01-02
# 2      3  Employee_3   29    Male    Finance  39500.0  2015-01-03
# 3      4  Employee_4   42    Male      Sales  35000.0  2015-01-04
# 4      5  Employee_5   40    Male    Finance  41500.0  2015-01-05
#
#    PerformanceScore  WorkHours
# 0               3.0       43.0
# 1               2.0       54.0
# 2               1.0       54.0
# 3               4.0       37.0
# 4               4.0       37.0

# %%
df.tail()
# Out:
#      EmpID           Name  Age  Gender Department   Salary JoiningDate  \
# 995    996   Employee_996   34  Female         HR  31000.0  2017-09-22
# 996    997   Employee_997   51  Female         IT  56500.0  2017-09-23
# 997    998   Employee_998   44    Male    Finance  98000.0  2017-09-24
# 998    999   Employee_999   40  Female      Sales  64500.0  2017-09-25
# 999   1000  Employee_1000   53  Female      Sales  86000.0  2017-09-26
#
#      PerformanceScore  WorkHours
# 995               2.0       36.0
# 996               1.0       44.0
# 997               4.0       51.0
# 998               1.0       53.0
# 999               5.0       40.0

# %%
df.isnull().sum()              # check missing values
df.fillna(df.mean(numeric_only=True), inplace=True)# fill NaN with mean
df.dropna()                    # drop rows with NaN
# Out:
#      EmpID           Name  Age  Gender Department   Salary JoiningDate  \
# 0        1     Employee_1   50  Female      Sales  90000.0  2015-01-01
# 1        2     Employee_2   36    Male    Finance  62500.0  2015-01-02
# 2        3     Employee_3   29    Male    Finance  39500.0  2015-01-03
# 3        4     Employee_4   42    Male      Sales  35000.0  2015-01-04
# 4        5     Employee_5   40    Male    Finance  41500.0  2015-01-05
# ..     ...            ...  ...     ...        ...      ...         ...
# 995    996   Employee_996   34  Female         HR  31000.0  2017-09-22
# 996    997   Employee_997   51  Female         IT  56500.0  2017-09-23
# 997    998   Employee_998   44    Male    Finance  98000.0  2017-09-24
# 998    999   Employee_999   40  Female      Sales  64500.0  2017-09-25
# 999   1000  Employee_1000   53  Female      Sales  86000.0  2017-09-26
#
#      PerformanceScore  WorkHours
# 0                 3.0       43.0
# 1                 2.0       54.0
# 2                 1.0       54.0
# 3                 4.0       37.0
# 4                 4.0       37.0
# ..                ...        ...
# 995               2.0       36.0
# 996               1.0       44.0
# 997               4.0       51.0
# 998               1.0       53.0
# 999               5.0       40.0
#
# [1000 rows x 9 columns]

# %%
df.isnull().sum()              # check missing values
df.fillna(0, inplace=True)     # fill NaN with 0
df.fillna(df.mean(numeric_only=True), inplace=True)  # fill NaN with mean
df.dropna()                    # remove rows with NaN
df.duplicated().sum()          # check duplicates
df.drop_duplicates(inplace=True)  # remove duplicates

# %%
df.groupby('Department')['Salary'].mean()
# Out:
# Department
# Finance      62483.173077
# HR           64678.213055
# IT           59035.502959
# Marketing    63694.335313
# Sales        62329.769926
# Name: Salary, dtype: float64

# %%
df.groupby('Department')['Salary'].agg(['mean','max','min','count'])
# Out:
#                     mean       max      min  count
# Department
# Finance     62483.173077   99500.0  25000.0    208
# HR          64678.213055  100000.0  25000.0    191
# IT          59035.502959   97500.0  25000.0    169
# Marketing   63694.335313  100000.0  25000.0    209
# Sales       62329.769926  100000.0  25500.0    223

# %%
#group by multiple columns
df.groupby(['Department','Age'])['Salary'].mean()
# Out:
# Department  Age
# Finance     22     63312.500000
#             23     70833.333333
#             24     54750.000000
#             25     69700.000000
#             26     73700.000000
#                        ...
# Sales       55     40900.000000
#             56     59142.857143
#             57     65857.142857
#             58     59285.714286
#             59     67000.000000
# Name: Salary, Length: 188, dtype: float64

# %%
df['Salary'].plot(kind='hist')     # histogram
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x='Department', y='PerformanceScore', kind='scatter')  # scatter plot
# Out:
# <Axes: xlabel='Department', ylabel='PerformanceScore'>

# %%
df['Salary'].plot(kind='box')      # boxplot
# Out:
# <Axes: >

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("employee_dataset.csv")
df.info()

# Convert columns to numeric 
df['Salary'] = pd.to_numeric(df['Salary'])
df['PerformanceScore'] = pd.to_numeric(df['PerformanceScore'])
df['WorkHours'] = pd.to_numeric(df['WorkHours'])

# Now handle missing values
df['Salary'].fillna(df['Salary'].mean(), inplace=True)
df['PerformanceScore'].fillna(df['PerformanceScore'].median(), inplace=True)
df['WorkHours'].fillna(df['WorkHours'].mean(), inplace=True)

print(df.isnull().sum())   # Check if missing values remain
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmpID             1000 non-null   int64
#  1   Name              1000 non-null   object
#  2   Age               1000 non-null   int64
#  3   Gender            1000 non-null   object
#  4   Department        1000 non-null   object
#  5   Salary            995 non-null    float64
#  6   JoiningDate       1000 non-null   object
#  7   PerformanceScore  823 non-null    float64
#  8   WorkHours         963 non-null    float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 70.4+ KB
# EmpID               0
# Name                0
# Age                 0
# Gender              0
# Department          0
# Salary              0
# JoiningDate         0
# PerformanceScore    0
# WorkHours           0
# dtype: int64
# C:\Users\123\AppData\Local\Temp\ipykernel_12904\2601811454.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].mean(), inplace=True)
# C:\Users\123\AppData\Local\Temp\ipykernel_12904\2601811454.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['PerformanceScore'].fillna(df['PerformanceScore'].median(), inplace=True)
# C:\Users\123\AppData\Local\Temp\ipykernel_12904\2601811454.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['WorkHours'].fillna(df['WorkHours'].mean(), inplace=True)
